# %% [markdown]
# # OPENROUTESERVICE
#
# API Services Include: **Directions**, **Isochrones**, Time-Distance Matrix, **Geocoding**, **Places Of Interest**, Elevation, Optimization
#
# https://www.youtube.com/watch?v=mgC-NMpegYg

# %% [markdown]
# # NOTES
# * for more information, visit python package index and search for openrouteservice
# * openrouteservice requires an API key
# * openrouteservice coordinates entered longitude, latitude however folium coordinates entered latitude, longitude

# %% [markdown]
# # IMPORTS

# %%
import openrouteservice as ors
import folium
from my_keys import openrouteservice_key

# %% [markdown]
# # API KEY REQUIRED
# vist https://openrouteservice.org to acquire API key

# %%
# performs requests to the ORS API services
# client will be used in all examples
client = ors.Client(key=openrouteservice_key)

# %% [markdown]
# # DIRECTIONS
#
# profile argument (string): specifies the mode of transport to use when calculating directions, options: driving-car, driving-hgv, foot-walking, foot-hiking, cycling-regular, cycling-road, cycling-mountain, cycling-electric

# %%
# coordinates from Kazan (55.849714011829505, 49.062195723827536) to Zelenodolsk (55.84622701236967, 48.51079707033782)
# order for coordinates is [lon, lat]
coordinates = [[49.062195723827536, 55.849714011829505], [48.51079707033782, 55.84622701236967]]

# directions
route = client.directions(coordinates=coordinates,
                          profile='driving-car',
                          format='geojson')

# map
map_directions = folium.Map(location=[55.84, 49.0], zoom_start=10)

# add geojson to map
folium.GeoJson(route, name='route').add_to(map_directions)

# add layer control to map (allows layer to be turned on or off)
folium.LayerControl().add_to(map_directions)

# display map
map_directions
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f65ee0e1b8466c42cc92d444555f6851 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f65ee0e1b8466c42cc92d444555f6851&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f65ee0e1b8466c42cc92d444555f6851 = L.map(
#                 &quot;map_f65ee0e1b8466c42cc92d444555f6851&quot;,
#                 {
#                     center: [55.84, 49.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3ee14a35ae047e56069e644219de7f63 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f65ee0e1b8466c42cc92d444555f6851);
#
#
#
#         function geo_json_5fca6fe143437d9206d2084b41163941_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_5fca6fe143437d9206d2084b41163941 = L.geoJson(null, {
#                 onEachFeature: geo_json_5fca6fe143437d9206d2084b41163941_onEachFeature,
#
#         });
#
#         function geo_json_5fca6fe143437d9206d2084b41163941_add (data) {
#             geo_json_5fca6fe143437d9206d2084b41163941
#                 .addData(data)
#                 .addTo(map_f65ee0e1b8466c42cc92d444555f6851);
#         }
#             geo_json_5fca6fe143437d9206d2084b41163941_add({&quot;bbox&quot;: [48.510794, 55.845374, 49.062205, 55.871747], &quot;features&quot;: [{&quot;bbox&quot;: [48.510794, 55.845374, 49.062205, 55.871747], &quot;geometry&quot;: {&quot;coordinates&quot;: [[49.062205, 55.849749], [49.06209, 55.849759], [49.061025, 55.849832], [49.060815, 55.849847], [49.059501, 55.849923], [49.057447, 55.850042], [49.055746, 55.850128], [49.055441, 55.850146], [49.054988, 55.850174], [49.053612, 55.850263], [49.053384, 55.850277], [49.050015, 55.850463], [49.049664, 55.850486], [49.048701, 55.850542], [49.047468, 55.850613], [49.041889, 55.850933], [49.041794, 55.850938], [49.039947, 55.851046], [49.039434, 55.85109], [49.039119, 55.851126], [49.038259, 55.851225], [49.032967, 55.85202], [49.032395, 55.852148], [49.031972, 55.852287], [49.031599, 55.852443], [49.030556, 55.852931], [49.02897, 55.853671], [49.02773, 55.854245], [49.027392, 55.854418], [49.027224, 55.854497], [49.027049, 55.854579], [49.026863, 55.854665], [49.026684, 55.85475], [49.024955, 55.85555], [49.02383, 55.856069], [49.0203, 55.857714], [49.019689, 55.858002], [49.019329, 55.858172], [49.018257, 55.858683], [49.016607, 55.859442], [49.01624, 55.859626], [49.014847, 55.860281], [49.013693, 55.860813], [49.011598, 55.861809], [49.011064, 55.86193], [49.01063, 55.861941], [49.002649, 55.861921], [49.001515, 55.861914], [49.001074, 55.861909], [49.000785, 55.861909], [49.000303, 55.861912], [48.996864, 55.861912], [48.991331, 55.8619], [48.97522, 55.861942], [48.971982, 55.86195], [48.970402, 55.862058], [48.968956, 55.862227], [48.968191, 55.862314], [48.967498, 55.862348], [48.966947, 55.862341], [48.964917, 55.862181], [48.964366, 55.862198], [48.963986, 55.862264], [48.963572, 55.862383], [48.963117, 55.862568], [48.962709, 55.862828], [48.961886, 55.863431], [48.961593, 55.863645], [48.960767, 55.864285], [48.958699, 55.865836], [48.958448, 55.865835], [48.956479, 55.86582], [48.955375, 55.86581], [48.954636, 55.865807], [48.954511, 55.865806], [48.953418, 55.865799], [48.951677, 55.865782], [48.949653, 55.865821], [48.948899, 55.865841], [48.946852, 55.865822], [48.94532, 55.865851], [48.944092, 55.865842], [48.942391, 55.86583], [48.942059, 55.86583], [48.941711, 55.865811], [48.941083, 55.865664], [48.940694, 55.865591], [48.940532, 55.86558], [48.94021, 55.865609], [48.939601, 55.865782], [48.939349, 55.865765], [48.939156, 55.865692], [48.938737, 55.865077], [48.938659, 55.864692], [48.938553, 55.864355], [48.938376, 55.864016], [48.938095, 55.863588], [48.937601, 55.863035], [48.937451, 55.862931], [48.937336, 55.862879], [48.93707, 55.862878], [48.936139, 55.863165], [48.933075, 55.864108], [48.931354, 55.864521], [48.93016, 55.864632], [48.929469, 55.864697], [48.928932, 55.864734], [48.92824, 55.864782], [48.92547, 55.864856], [48.922063, 55.864883], [48.918104, 55.86484], [48.915494, 55.864717], [48.914185, 55.864655], [48.91392, 55.864643], [48.911993, 55.86455], [48.910209, 55.864465], [48.908475, 55.864382], [48.905824, 55.864192], [48.903827, 55.864052], [48.90164, 55.863844], [48.899083, 55.863624], [48.897889, 55.863548], [48.895686, 55.863408], [48.894607, 55.863337], [48.893379, 55.863262], [48.891051, 55.863102], [48.887212, 55.862736], [48.886885, 55.862704], [48.886891, 55.862096], [48.886738, 55.861793], [48.886715, 55.861526], [48.886746, 55.861382], [48.886845, 55.861244], [48.88724, 55.860678], [48.88741, 55.86019], [48.887509, 55.859627], [48.887512, 55.859542], [48.887618, 55.859037

# %% [markdown]
# ### view trip information using json data

# %%
# distance and duration
print(route['features'][0]['properties']['segments'][0]['distance']*0.000621371, 'miles')
print(route['features'][0]['properties']['segments'][0]['duration']*0.000277778, 'hours\n')

# distances are in meters
# timings are in seconds
print('directions')
for index, i in enumerate(route['features'][0]['properties']['segments'][0]['steps']):
    print(index+1, i, '\n')
# Out:
# 23.996043140900003 miles
# 0.7865006292000001 hours
#
# directions
# 1 {'distance': 7070.2, 'duration': 608.5, 'type': 11, 'instruction': 'Head west on Тэцевская улица', 'name': 'Тэцевская улица', 'way_points': [0, 69]}
#
# 2 {'distance': 1201.5, 'duration': 131.0, 'type': 0, 'instruction': 'Turn left onto Тэцевская улица', 'name': 'Тэцевская улица', 'way_points': [69, 89]}
#
# 3 {'distance': 367.6, 'duration': 37.5, 'type': 12, 'instruction': 'Keep left', 'name': '-', 'way_points': [89, 99]}
#
# 4 {'distance': 3210.3, 'duration': 299.0, 'type': 5, 'instruction': 'Turn slight right onto проспект Заречье', 'name': 'проспект Заречье', 'way_points': [99, 127]}
#
# 5 {'distance': 1434.3, 'duration': 118.3, 'type': 0, 'instruction': 'Turn left onto улица Нурихана Фаттаха', 'name': 'улица Нурихана Фаттаха', 'way_points': [127, 157]}
#
# 6 {'distance': 97.2, 'duration': 7.8, 'type': 3, 'instruction': 'Turn sharp right onto Залесная улица', 'name': 'Залесная улица', 'way_points': [157, 158]}
#
# 7 {'distance': 1108.2, 'duration': 84.6, 'type': 6, 'instruction': 'Continue straight onto Залесная улица', 'name': 'Залесная улица', 'way_points': [158, 169]}
#
# 8 {'distance': 782.0, 'duration': 43.3, 'type': 12, 'instruction': 'Keep left onto Залесная улица', 'name': 'Залесная улица', 'way_points': [169, 176]}
#
# 9 {'distance': 577.4, 'duration': 46.1, 'type': 12, 'instruction': 'Keep left', 'name': '-', 'way_points': [176, 182]}
#
# 10 {'distance': 11869.7, 'duration': 512.9, 'type': 6, 'instruction': 'Continue straight onto А-295', 'name': 'А-295', 'way_points': [182, 250]}
#
# 11 {'distance': 387.2, 'duration': 17.4, 'type': 12, 'instruction': 'Keep left onto А-295', 'name': 'А-295', 'way_points': [250, 255]}
#
# 12 {'distance': 542.7, 'duration': 24.4, 'type': 6, 'instruction': 'Continue straight onto А-295', 'name': 'А-295', 'way_points': [255, 257]}
#
# 13 {'distance': 6945.7, 'duration': 569.0, 'type': 6, 'instruction': 'Continue straight onto 16К-1800', 'name': '16К-1800', 'way_points': [257, 321]}
#
# 14 {'distance': 94.7, 'duration': 9.7, 'type': 1, 'instruction': 'Turn right', 'name': '-', 'way_points': [321, 322]}
#
# 15 {'distance': 1800.1, 'duration': 186.5, 'type': 13, 'instruction': 'Keep right', 'name': '-', 'way_points': [322, 364]}
#
# 16 {'distance': 301.3, 'duration': 39.1, 'type': 0, 'instruction': 'Turn left onto улица Заикина', 'name': 'улица Заикина', 'way_points': [364, 372]}
#
# 17 {'distance': 767.1, 'duration': 81.7, 'type': 7, 'instruction': 'Enter the roundabout and take the 1st exit', 'name': '-', 'exit_number': 1, 'way_points': [372, 391]}
#
# 18 {'distance': 19.4, 'duration': 4.6, 'type': 1, 'instruction': 'Turn right', 'name': '-', 'way_points': [391, 393]}
#
# 19 {'distance': 41.3, 'duration': 9.9, 'type': 0, 'instruction': 'Turn left', 'name': '-', 'way_points': [393, 394]}
#
# 20 {'distance': 0.0, 'duration': 0.0, 'type': 10, 'instruction': 'Arrive at your destination, on the right', 'name': '-', 'way_points': [394, 394]}

# %% [markdown]
# # ISOCHRONES
# An isochrone map depicts the area accessible from a point within a certain time threshold.
#
# Reachable or accessible areas can be shown graphically by isochrones. Isochrones are imaginary lines passing through all the places that can be reached from a particular origin within a specified travel time.

# %%
# coordinates
coordinates = [[-80.127995, 25.784097]]

# isochrone
isochrone = client.isochrones(locations=coordinates,
                              range_type='time',
                              # 900 seconds, 15 minutes
                              range=[900],
                              attributes=['total_pop'])

# map
map_isochrone = folium.Map(location=[25.784097, -80.127995], tiles='cartodbpositron', zoom_start=12)

# add geojson to map with population
population = isochrone['features'][0]['properties']['total_pop']
folium.GeoJson(isochrone, name='isochrone', tooltip=f'population: {population:,.0f}').add_to(map_isochrone)

# add marker to map
minutes = isochrone['features'][0]['properties']['value']/60
popup_message = f'outline shows areas reachable within {minutes} minutes'
folium.Marker([25.784097, -80.127995], popup=popup_message, tooltip='click').add_to(map_isochrone)

# add layer control to map (allows layer to be turned on or off)
folium.LayerControl().add_to(map_isochrone)

# display map
map_isochrone
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f069cf72c30b37e0dc323baf78ea0aa3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f069cf72c30b37e0dc323baf78ea0aa3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f069cf72c30b37e0dc323baf78ea0aa3 = L.map(
#                 &quot;map_f069cf72c30b37e0dc323baf78ea0aa3&quot;,
#                 {
#                     center: [25.784097, -80.127995],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4bc2d2cf121d8a1e92cec1f1a7ffe5f4 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f069cf72c30b37e0dc323baf78ea0aa3);
#
#
#
#         function geo_json_e65b23f429d5ff7ae9fed6b29b52c2b1_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_e65b23f429d5ff7ae9fed6b29b52c2b1 = L.geoJson(null, {
#                 onEachFeature: geo_json_e65b23f429d5ff7ae9fed6b29b52c2b1_onEachFeature,
#
#         });
#
#         function geo_json_e65b23f429d5ff7ae9fed6b29b52c2b1_add (data) {
#             geo_json_e65b23f429d5ff7ae9fed6b29b52c2b1
#                 .addData(data)
#                 .addTo(map_f069cf72c30b37e0dc323baf78ea0aa3);
#         }
#             geo_json_e65b23f429d5ff7ae9fed6b29b52c2b1_add({&quot;bbox&quot;: [-80.209607, 25.764987, -80.119349, 25.843679], &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-80.209607, 25.789999], [-80.208207, 25.786682], [-80.204257, 25.78455], [-80.195239, 25.778076], [-80.191394, 25.775313], [-80.191279, 25.775317], [-80.188466, 25.776361], [-80.18669, 25.778212], [-80.177258, 25.783828], [-80.174578, 25.782203], [-80.171026, 25.778539], [-80.168729, 25.777541], [-80.162624, 25.774893], [-80.15296, 25.769455], [-80.149574, 25.767773], [-80.147683, 25.766802], [-80.145792, 25.765831], [-80.134165, 25.764987], [-80.131817, 25.773194], [-80.130483, 25.783988], [-80.12954, 25.786705], [-80.128293, 25.796204], [-80.12454, 25.804808], [-80.123729, 25.808335], [-80.123316, 25.811048], [-80.122752, 25.814748], [-80.121978, 25.824871], [-80.120709, 25.834304], [-80.119444, 25.838268], [-80.119349, 25.841231], [-80.119382, 25.841323], [-80.1196, 25.84161], [-80.121066, 25.842318], [-80.129898, 25.843679], [-80.130403, 25.843263], [-80.131521, 25.840509], [-80.131484, 25.829761], [-80.136202, 25.826001], [-80.137868, 25.824045], [-80.140458, 25.814472], [-80.146985, 25.812315], [-80.150444, 25.81235], [-80.153512, 25.812409], [-80.156081, 25.812434], [-80.158651, 25.812458], [-80.161714, 25.812488], [-80.164382, 25.812513], [-80.166951, 25.812538], [-80.169941, 25.812566], [-80.173245, 25.812564], [-80.176512, 25.812595], [-80.186466, 25.815065], [-80.186576, 25.815064], [-80.192345, 25.813294], [-80.192397, 25.809694], [-80.192722, 25.79985], [-80.195641, 25.796028], [-80.203049, 25.79277], [-80.206309, 25.791242], [-80.209095, 25.790215], [-80.209607, 25.789999]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;center&quot;: [-80.12995023570844, 25.78392291331119], &quot;group_index&quot;: 0, &quot;total_pop&quot;: 80626.0, &quot;value&quot;: 900.0}, &quot;type&quot;: &quot;Feature&quot;}], &quot;metadata&quot;: {&quot;attribution&quot;: &quot;openrouteservice.org | OpenStreetMap contributors&quot;, &quot;engine&quot;: {&quot;build_date&quot;: &quot;2022-10-21T14:34:31Z&quot;, &quot;graph_date&quot;: &quot;2023-02-05T14:40:53Z&quot;, &quot;version&quot;: &quot;6.8.0&quot;}, &quot;query&quot;: {&quot;attributes&quot;: [&quot;total_pop&quot;], &quot;locations&quot;: [[-80.127995, 25.784097]], &quot;profile&quot;: &quot;driving-car&quot;, &quot;range&quot;: [900.0], &quot;range_type&quot;: &quot;time&quot;}, &quot;service&quot;: &quot;isochrones&quot;, &quot;timestamp&quot;: 1676143821966}, &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_e65b23f429d5ff7ae9fed6b29b52c2b1.bindTooltip(
#                 `&lt;div&gt;
#                      population: 80,626
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cc574b6158d151b5d1c37dfc3dd185b4 = L.marker(
#                 [25.784097, -80.127995],
#                 {}
#             ).addTo(map_f069cf72c30b37e0dc323baf78ea0aa3);
#
#
#         var popup_9639c882fdf11403ee7de974c672ab04 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a4588e14656bb47bd99e8eb7a38c1e5b = $(`&lt;div id=&quot;html_a4588e14656bb47bd99e8eb7a38c1e5b&quot; style=&quot;wi

# %% [markdown]
# # PELIAS GEOCODING

# %%
# map
map_geocode = folium.Map(location=[31.7755, -106.4664], tiles='cartodbpositron', zoom_start=13)

# address
address = '4001 E Paisano Dr, El Paso, TX, 79905'

# geocode
geocode = client.pelias_search(text=address, focus_point=list(reversed(map_geocode.location)))

# add marker to map (El Paso Zoo)
for result in geocode['features']:
    folium.Marker(location=list(reversed(result['geometry']['coordinates'])),
                  icon=folium.Icon(icon='building', color='green', prefix='fa'),
                  popup=folium.Popup(result['properties']['name'])).add_to(map_geocode)

# display map
map_geocode
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b0749e302803b60a5a99122e63efca6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b0749e302803b60a5a99122e63efca6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0b0749e302803b60a5a99122e63efca6 = L.map(
#                 &quot;map_0b0749e302803b60a5a99122e63efca6&quot;,
#                 {
#                     center: [31.7755, -106.4664],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_75e8ceb221b788e60c8b13cd05415eb0 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0b0749e302803b60a5a99122e63efca6);
#
#
#             var marker_0cc408ca3e17b196a946ed3e6ddff3ba = L.marker(
#                 [31.768983, -106.443814],
#                 {}
#             ).addTo(map_0b0749e302803b60a5a99122e63efca6);
#
#
#             var icon_799a0515270e10e2751aaa83785a73d8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_0cc408ca3e17b196a946ed3e6ddff3ba.setIcon(icon_799a0515270e10e2751aaa83785a73d8);
#
#
#         var popup_a94ff3ff8688495ad86be3ce66bb4226 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2aa54b146246c8c11dafb6e5b658bb16 = $(`&lt;div id=&quot;html_2aa54b146246c8c11dafb6e5b658bb16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4001 East Paisano Drive&lt;/div&gt;`)[0];
#                 popup_a94ff3ff8688495ad86be3ce66bb4226.setContent(html_2aa54b146246c8c11dafb6e5b658bb16);
#
#
#
#         marker_0cc408ca3e17b196a946ed3e6ddff3ba.bindPopup(popup_a94ff3ff8688495ad86be3ce66bb4226)
#         ;
#
#
#
#
#             var marker_b27bd6d1bd566617b2a81883c9e0e270 = L.marker(
#                 [31.768608, -106.444054],
#                 {}
#             ).addTo(map_0b0749e302803b60a5a99122e63efca6);
#
#
#             var icon_a8ed1167638fc3a6751d5b1e51f68339 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_b27bd6d1bd566617b2a81883c9e0e270.setIcon(icon_a8ed1167638fc3a6751d5b1e51f68339);
#
#
#         var popup_bc3f2f185c981ae895f6fe3261a50224 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a753e45d4e451168de20eca5f3a392c3 = $(`&lt;div id=&quot;html_a753e45d4e451168de20eca5f3a392c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4001 East Paisano Dr Wb&lt;/div&gt;`)[0];
#                 popup_bc3f2f185c981ae895f6fe3261a50224.setContent(html_a753e45d4e451168de20eca5f3a392c3);
#
#
#
#         marker_b27bd6d1bd566617b2a81883c9e0e270.bindPopup(popup_bc3f2f185c981ae895f6fe3261a50224)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # POIS - PLACES OF INTEREST
# filter_category_ids = https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml

# %%
# coordinates
geojson = {"type": "point", "coordinates": [-106.435073, 31.774464]}
coordinates = [31.774464, -106.435073]

# places of interest
pois = client.places(request='pois',
                     geojson=geojson,
                     # buffer searches (in meters) around specified point
                     buffer=2000,
                     # hospital: 206, restaurant: 570
                     filter_category_ids=[206, 570])

# map
map_pois = folium.Map(location=coordinates, tiles='cartodbpositron', zoom_start=14)

# add center point
folium.Marker(coordinates, icon=folium.Icon(color='red')).add_to(map_pois)

# add search area circle
folium.Circle(radius=2000, location=coordinates, color='green').add_to(map_pois)

# add markers to map
for poi in pois['features']:
    folium.Marker(location=list(reversed(poi['geometry']['coordinates'])),
                  icon=folium.Icon(color='blue'),
                  popup=folium.Popup(poi['properties']['osm_tags']['name'])).add_to(map_pois)

# display map
map_pois
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b7c1da1a6efa9261f6948a23cda2bdd3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b7c1da1a6efa9261f6948a23cda2bdd3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b7c1da1a6efa9261f6948a23cda2bdd3 = L.map(
#                 &quot;map_b7c1da1a6efa9261f6948a23cda2bdd3&quot;,
#                 {
#                     center: [31.774464, -106.435073],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2b612aa1360314d3028329f501b16e18 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b7c1da1a6efa9261f6948a23cda2bdd3);
#
#
#             var marker_c3cba286be0636a4a6ae004b89fd3a54 = L.marker(
#                 [31.774464, -106.435073],
#                 {}
#             ).addTo(map_b7c1da1a6efa9261f6948a23cda2bdd3);
#
#
#             var icon_60d2b49cb47091bb758a3e86ab8cba5f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c3cba286be0636a4a6ae004b89fd3a54.setIcon(icon_60d2b49cb47091bb758a3e86ab8cba5f);
#
#
#             var circle_bfb9fcf538487497fd86dc8989fcac9e = L.circle(
#                 [31.774464, -106.435073],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b7c1da1a6efa9261f6948a23cda2bdd3);
#
#
#             var marker_d2b9be2075532c3d8ae046b6f27edb49 = L.marker(
#                 [31.779435, -106.449883],
#                 {}
#             ).addTo(map_b7c1da1a6efa9261f6948a23cda2bdd3);
#
#
#             var icon_810cb5994af9166aaf92e3cf0a3ed22b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d2b9be2075532c3d8ae046b6f27edb49.setIcon(icon_810cb5994af9166aaf92e3cf0a3ed22b);
#
#
#         var popup_c9a6c043bfeb33518b6ae959da799ad6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fa49ef283cace1a9dc03ee9286cffddc = $(`&lt;div id=&quot;html_fa49ef283cace1a9dc03ee9286cffddc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;L &amp; J Cafe&lt;/div&gt;`)[0];
#                 popup_c9a6c043bfeb33518b6ae959da799ad6.setContent(html_fa49ef283cace1a9dc03ee9286cffddc);
#
#
#
#         marker_d2b9be2075532c3d8ae046b6f27edb49.bindPopup(popup_c9a6c043bfeb33518b6ae959da799ad6)
#         ;
#
#
#
#
#             var marker_37629867869f05f6805792e64ebb4a7a = L.marker(
#                 [31.771707, -106.434647],
#                 {}
#             ).addTo(map_b7c1da1a6efa9261f6948a23cda2bdd3);
#
#
#             var icon_5bbca40988eb4dd791669d2b2accecf3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_37629867869f05f6805792e64ebb4a7a.setIcon(icon_5bbca40988eb4dd791669d2b2accecf3);
#
#
#         var popup_1493a207231089469dd9f2b86c6147df = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6497d6d90d591cb051cec83c1df7d77c = $(`&lt;div id=&quot;html_6497d6d90d591cb051cec83c1df7d77c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;University Medical Center&lt;/div&gt;`)[0];
#                 popup_1493a207231089469dd9f2b86c6147df.setContent(html_6497d6d90d591cb051cec83c1df7d77c);
#
#
#
#         marker_37629867869f05f6805792e64ebb4a7a.bindPopup(popup_1493a207231089469dd9f2b86c6147df)
#         ;
#
#
#
#
#             var marker_a1f9d884154493d0f080b786123d1c11 = L.marker(
#                 [31.772, -106.43622],
